# %%
print ("Hello World")
# Out:
# Hello World

# %%
word_file = open("data/count_1w.txt", "r")

i = 0
for line in word_file:
    words = line.split('\t')
    freq = int(words[1].replace('\n', ''))
    i += 1
    if i > 1000:
        break
# Out:
# 23135851162
# ['the', '23135851162\n']
# 13151942776
# ['of', '13151942776\n']
# 12997637966
# ['and', '12997637966\n']
# 12136980858
# ['to', '12136980858\n']
# 9081174698
# ['a', '9081174698\n']
# 8469404971
# ['in', '8469404971\n']
# 5933321709
# ['for', '5933321709\n']
# 4705743816
# ['is', '4705743816\n']
# 3750423199
# ['on', '3750423199\n']
# 3400031103
# ['that', '3400031103\n']
# 3350048871
# ['by', '3350048871\n']
# 3228469771
# ['this', '3228469771\n']
# 3183110675
# ['with', '3183110675\n']
# 3086225277
# ['i', '3086225277\n']
# 2996181025
# ['you', '2996181025\n']
# 2813163874
# ['it', '2813163874\n']
# 2633487141
# ['not', '2633487141\n']
# 2590739907
# ['or', '2590739907\n']
# 2398724162
# ['be', '2398724162\n']
# 2393614870
# ['are', '2393614870\n']
# 2275595356
# ['from', '2275595356\n']
# 2272272772
# ['at', '2272272772\n']
# 2247431740
# ['as', '2247431740\n']
# 2062066547
# ['your', '2062066547\n']
# 2022459848
# ['all', '2022459848\n']
# 1564202750
# ...
